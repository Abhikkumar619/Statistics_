# %% [markdown]
# Q1: What is Estimation Statistics? Explain point estimate and interval estimate.

# %%
"""
The process by which the one makes inferences about a population, based on information 
from sample is estimation statistics.

Types of estimate statistics:
1. point estimate: The single numerical value used to estimate the unknown population 
                     parameter is point.
                Example: sample mean is point estimate of population.
            
2. Interval estimate: It is range of value to estimate the unknown population paremeter.
                       interval estimate is also called a confidence interval.

# %% [markdown]
# Q2. Write a Python function to estimate the population mean using a sample mean and standard
# deviation.

# %%
def population_estimater(sample_mean, sample_std_deviation, sample_size, z_score):
    import math
    pop_men=sample_mean+(z_score *(sample_std_deviation/math.sqrt(sample_size)))
    return pop_men

# %%
population_estimater(1.2, 0.3, 12, 1.91)
# Out:
# 1.3654108521228276

# %% [markdown]
# Q3: What is Hypothesis testing? Why is it used? State the importance of Hypothesis testing.

# %%
"""
Hypothesis testing is a type of statistical analysis in which we put our assumpution about a 
population parameter to test.it is used to estimate the relationship between statistical variable.

Importance: 
1. It allows the resarcher to determine whether the data from the sample is statistcally significant.
2. It is most importance processes for measuring the validity and reliability of outcomes in any systematic 
   investigation.
3. It helps the researcher to successfully extropolate data from sample to larger poplation.

# %% [markdown]
# 4. Create a hypothesis that states whether the average weight of male college students is greater than
# the average weight of female college students.

# %%
"""
1. Null hypithesis : mean_of_male = mean_of women.
2. Alternative_hypothesis : mean_of_male != mean of women

# %% [markdown]
# Q5. Write a Python script to conduct a hypothesis test on the difference between two population means,
# given a sample from each population.

# %% [markdown]
# Q6: What is a null and alternative hypothesis? Give some examples.

# %%
"""
Null hypothesis: 
The assumption you are beginning with data is Null hypothesis.
Example: The person is guilty.
         
Alternative Hypothesis :
The opposite of null hypothesis is alternative hypothesis 
 Example: The person is guilty.

# %% [markdown]
# Q7: Write down the steps involved in hypothesis testing.

# %%
"""
The steps required to hypotheis testing is: 
1. Null hypothesis 
2. Alternative hypothesis.
3. statistical analyesis.
4. Conclusion of hypothesis

# %% [markdown]
# Q8. Define p-value and explain its significance in hypothesis testing.

# %%
"""
The p value is a number, calculated from a statistical test, that describes. how likely you are to have found a particular det
of observation if the null hypothesis where true, p value are used in hypothesis testing to help decide whether to reject the null hypthesis.

-Significance in hypothesis testing
1.The level of statistical significance is usually represented as a P-value between 0 and 1. The smaller the p-value, the more likely it is that you would
  reject the null hypothesis.
A P-Value < or = 0.05 is considered statistically significant. It denotes strong evidence against the null hypothesis, since there is below 5% probability of the null being correct.
  So, we reject the null hypothesis and accept the alternative hypothesis.

# %% [markdown]
# Q9. Generate a Student's t-distribution plot using Python's matplotlib library, with the degrees of freedom
# parameter set to 10.

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import t

df = 10  # degrees of freedom
x = np.linspace(t.ppf(0.001, df), t.ppf(0.999, df), 100)  # x values
pdf = t.pdf(x, df)  # probability density function values

plt.plot(x, pdf, label='t-distribution')
plt.legend()
plt.title(f"Student's t-distribution with {df} degrees of freedom")
plt.xlabel('x')
plt.ylabel('Probability density')
plt.show()

# %% [markdown]
# Q10. Write a Python program to calculate the two-sample t-test for independent samples, given two random samples of equal size and a null hypothesis that the population means are equal.

# %%
import numpy as np
from scipy.stats import ttest_ind
# Generate two random samples of equal size
sample1 = np.random.normal(loc=10, scale=2, size=50)
sample2 = np.random.normal(loc=12, scale=2, size=50)

# Calculate the t-test
t_statistic, p_value = ttest_ind(sample1, sample2, equal_var=True)

# Print the results
print("T-statistic: ", t_statistic)
print("P-value: ", p_value)

# Interpret the results
alpha = 0.05  # significance level
if p_value < alpha:
    print("Reject null hypothesis. There is sufficient evidence to suggest that the population means are different.")
else:
    print("Fail to reject null hypothesis. There is not sufficient evidence to suggest that the population means are different.")
# Out:
# T-statistic:  -4.562075769646727
# P-value:  1.468292872981212e-05
# Reject null hypothesis. There is sufficient evidence to suggest that the population means are different.

# %% [markdown]
# Q11: What is Student’s t distribution? When to use the t-Distribution.

# %%
"""
The t-distribution is student t-distrubution is type of probability distribution that is similar to the noraml distribution 
with its bell shape but has havier tails. it is used to estimating population parameter for small sample sizes of unknown variance.


Satistical analysis using z-score we need population standard deviation usually. it is very diffeculty to find 
population standerd deviation, if we do not have population standard deviation
than we use t-distrubution.

"""

# %% [markdown]
# Q12: What is t-statistic? State the formula for t-statistic.

# %%
"""
The statistical test used to compare the means of two groups of data 
is t-statistic.
T=mean1-mean2/s(diff)/root(n)

# %% [markdown]
# Q13. A coffee shop owner wants to estimate the average daily revenue for their shop. They take a random
# sample of 50 days and find the sample mean revenue to be $500 with a standard deviation of $50.
# Estimate the population mean revenue with a 95% confidence interval.

# %%
"""
n=50
sample_mean=500$
sample_std=50
CI=95% =0.95

siginifance_value=1-CI
                = 1-0.95
                =0.05
degree of freedom= n-1
                 =50-1
                 =49
    
standard_error = sample_std/squrt(n)
               = 50/squrt(50)
               =7.07
               
Area under curve using t-table= 2.009

confidence interval = 500 +-(2.009)*(7.07)
                    = (485.80, 514.20)

The population mean revenue is  (485.80, 514.20)

"""

# %% [markdown]
# Q14. A researcher hypothesizes that a new drug will decrease blood pressure by 10 mmHg. They conduct a
# clinical trial with 100 patients and find that the sample mean decrease in blood pressure is 8 mmHg with a
# standard deviation of 3 mmHg. Test the hypothesis with a significance level of 0.05.

# %%
"""
n=100
sample_mean=  8 mmhg
sample_std= 3 mmhg
significance_value=0.05.

1. null hypothesis(h0): sample_mean = 10 mmhg
2. Alternate hypothesis(h1): sample_mean < 10 mmhg (1 tail test)

Degree of freedom= n-1 
                 = 100-1
                 =99

Area_under_curve = 1.6603

t-value= sample_mean- U/ sample_std/ sqrt(100)
       = 90/3.33
       = 27.0027
       
if  t test is less than +1.6603 than we reject the null hypthesis.
 = 27.0027 > 1.6603
conclusion: The t test is grater than 1.6603 than we accept the null hypothesis.
"""

# %% [markdown]
# Q15. An electronics company produces a certain type of product with a mean weight of 5 pounds and a
# standard deviation of 0.5 pounds. A random sample of 25 products is taken, and the sample mean weight
# is found to be 4.8 pounds. Test the hypothesis that the true mean weight of the products is less than 5
# pounds with a significance level of 0.01.

# %%
"""
mean= 5
std=0.5
n= 25
sample_mean= 4.8
significance_value=0.01.
Test the hypthesis that true mean weight of product is less than 5 pounds.

1. Null_hypothisis : mean= 5 pounds.
2. Alternative hypothesis : mean < 5 pounds.

significan_value= 0.001
CI= 0.99

z_test= sample_mean-mean/std/sqrt(n)
      = -0.2/0.1
      = -2
      
area_under_curve= 0.228

if significan_value < 0.228 so ewe reject the null hypothesis.
"""

# %% [markdown]
# Q16. Two groups of students are given different study materials to prepare for a test. The first group (n1 =
# 30) has a mean score of 80 with a standard deviation of 10, and the second group (n2 = 40) has a mean
# score of 75 with a standard deviation of 8. Test the hypothesis that the population means for the two
# groups are equal with a significance level of 0.01.

# %%
"""
n1= 20 
mean1= 80
std1= 10

n2= 40
mean2= 75
std2= 8

1. Null_ hypothesis : std1= std2
2. Alternative_hypothesis : std1 != std2

calculation of variance_ratio.
f= std1/std2
 = 10/8
 =1.25
 
 Decision Rules
 df1=30-1
   = 29
 df2= 40-1
    = 39
    
critiacal_value= 2.2290
 1. 25 < 2.2290 we fail to reject the null hypothesis.

# %% [markdown]
# Q17. A marketing company wants to estimate the average number of ads watched by viewers during a TV
# program. They take a random sample of 50 viewers and find that the sample mean is 4 with a standard
# deviation of 1.5. Estimate the population mean with a 99% confidence interval.

# %%
"""
n=50
sample_mean=4 
sample_std= 1.5
CI = 0.99
significance_value= 0.01

standard_error= sample_std/ sqrt(n)
              = 1.05/7.071
              = 0.2121
            
T-value= +- 2.6799

confidence_interval= 4 +-(2.6799) *(0.2121)
                   = (+4.5663, -3.4347)
